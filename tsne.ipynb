# %%
import pandas as pd

# %%
image_annos = pd.read_csv(
    f'celebA_train_500/celebA_anno.txt',
    sep=' ',
    names=['Image', 'Target'])

# %%
image_annos
# Out:
#             Image  Target
# 0      000001.jpg       0
# 1      000404.jpg       0
# 2      003415.jpg       0
# 3      004390.jpg       0
# 4      018062.jpg       0
# ...           ...     ...
# 12006  126297.jpg     499
# 12007  129725.jpg     499
# 12008  132679.jpg     499
# 12009  151415.jpg     499
# 12010  154504.jpg     499
#
# [12011 rows x 2 columns]

# %%
targets = image_annos['Target']
targets
# Out:
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
#         ...
# 12006    499
# 12007    499
# 12008    499
# 12009    499
# 12010    499
# Name: Target, Length: 12011, dtype: int64

# %%
# %%sql

# %%
from collections  import Counter

# %%
c = Counter(i for i in targets)

# %%
c
# Out:
# Counter({0: 30,
#          1: 30,
#          2: 30,
#          3: 30,
#          4: 25,
#          5: 30,
#          6: 30,
#          7: 30,
#          8: 30,
#          9: 29,
#          10: 25,
#          11: 22,
#          12: 20,
#          13: 30,
#          14: 30,
#          15: 30,
#          16: 20,
#          17: 30,
#          18: 29,
#          19: 25,
#          20: 5,
#          21: 30,
#          22: 29,
#          23: 30,
#          24: 28,
#          25: 23,
#          26: 11,
#          27: 30,
#          28: 20,
#          29: 28,
#          30: 25,
#          31: 20,
#          32: 15,
#          33: 30,
#          34: 30,
#          35: 30,
#          36: 24,
#          37: 30,
#          38: 29,
#          39: 21,
#          40: 22,
#          41: 24,
#          42: 30,
#          43: 30,
#          44: 30,
#          45: 30,
#          46: 30,
#          47: 30,
#          48: 20,
#          49: 30,
#          50: 30,
#          51: 12,
#          52: 30,
# ...

# %%
weights = [1/c.get(i) for i in targets]

# %%
weights
# Out:
# [0.03333333333333333,
#  0.03333333333333333,
#  0.03333333333333333,
#  0.03333333333333333,
#  0.03333333333333333,
#  0.03333333333333333,
#  0.03333333333333333,
#  0.03333333333333333,
#  0.03333333333333333,
#  0.03333333333333333,
#  0.03333333333333333,
#  0.03333333333333333,
#  0.03333333333333333,
#  0.03333333333333333,
#  0.03333333333333333,
#  0.03333333333333333,
#  0.03333333333333333,
#  0.03333333333333333,
#  0.03333333333333333,
#  0.03333333333333333,
#  0.03333333333333333,
#  0.03333333333333333,
#  0.03333333333333333,
#  0.03333333333333333,
#  0.03333333333333333,
#  0.03333333333333333,
#  0.03333333333333333,
#  0.03333333333333333,
#  0.03333333333333333,
#  0.03333333333333333,
#  0.03333333333333333,
#  0.03333333333333333,
#  0.03333333333333333,
#  0.03333333333333333,
#  0.03333333333333333,
#  0.03333333333333333,
#  0.03333333333333333,
#  0.03333333333333333,
#  0.03333333333333333,
#  0.03333333333333333,
#  0.03333333333333333,
# ...

# %%
from torchvision.models import resnet18
